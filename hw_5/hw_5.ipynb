# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Исходный код программы для генерации данных на С++ лежит в репозитории

# %% [markdown]
# # Confusion Maxtrix metrics

# %%
#Точки 50/50
exp1 = pd.read_csv('exp1.csv')
exp1.dropna()
exp1.plot(0, [1, 2, 3, 4, 5], subplots=True, figsize=(10, 14))
# Out:
# array([<AxesSubplot:xlabel='threshold'>, <AxesSubplot:xlabel='threshold'>,
#        <AxesSubplot:xlabel='threshold'>, <AxesSubplot:xlabel='threshold'>,
#        <AxesSubplot:xlabel='threshold'>], dtype=object)

# %%
#Точки 5/95
exp1 = pd.read_csv('exp2.csv')
exp1.dropna()
exp1.plot(0, [1, 2, 3, 4, 5], subplots=True, figsize=(10, 14))
# Out:
# array([<AxesSubplot:xlabel='threshold'>, <AxesSubplot:xlabel='threshold'>,
#        <AxesSubplot:xlabel='threshold'>, <AxesSubplot:xlabel='threshold'>,
#        <AxesSubplot:xlabel='threshold'>], dtype=object)

# %% [markdown]
# # ROC

# %%
exp2 = pd.read_csv('exp2.csv')
plt = exp2.plot(1, 0)
plt.set_xlim(0, 7000)
plt.grid(True)

# %%
exp3 = pd.read_csv('exp3.csv')
exp3.plot(0, [1], subplots=True)
# Out:
# array([<AxesSubplot:xlabel='False Positive'>], dtype=object)

# %%
exp4 = pd.read_csv('exp4.csv')
exp4.plot(0, [1], subplots=True)
# Out:
# array([<AxesSubplot:xlabel='False Positive'>], dtype=object)
